# %%
import os

# %%
os.getcwd()

# %%
os.chdir("insert_path")

# %%
#directory = 'c:/users/fre_f/pythonprojects/cellvision/yolo/data/patched/train/masks/'

for filename in os.listdir():
    os.rename(filename, filename.replace('_cp_masks', ''))
